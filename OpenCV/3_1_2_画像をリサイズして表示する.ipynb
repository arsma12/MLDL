# %%
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

img = cv2.imread("3_1_2_test.png")

#画像をリサイズする
im2 = cv2.resize(img, (600,300))

# リサイズした画像を保存
cv2.imwrite("3_1_2_out-resize.png", im2)

#画像を表示
plt.imshow(cv2.cvtColor(im2,cv2.COLOR_BGR2RGB))
plt.show()
